# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('large_ecommerce_sales_data.csv')

# %%
df.head()
# Out:
#    Order_ID  Customer_Age  Gender        Product     Category  Price  \
# 0         1            64    Male     Face Cream       Beauty   1627
# 1         2            43  Female         Tablet  Electronics    165
# 2         3            62  Female  Tennis Racket       Sports   1367
# 3         4            56  Female       Lipstick       Beauty   1078
# 4         5            35    Male         Laptop  Electronics   1940
#
#    Quantity  Total_Spend  Order_Date
# 0         4         6508  2023-07-02
# 1         3          495  2023-05-04
# 2         4         5468  2023-10-15
# 3         5         5390  2023-03-15
# 4         2         3880  2023-05-24

# %%
df.shape
# Out:
# (500, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order_ID      500 non-null    int64
#  1   Customer_Age  500 non-null    int64
#  2   Gender        500 non-null    object
#  3   Product       500 non-null    object
#  4   Category      500 non-null    object
#  5   Price         500 non-null    int64
#  6   Quantity      500 non-null    int64
#  7   Total_Spend   500 non-null    int64
#  8   Order_Date    500 non-null    object
# dtypes: int64(5), object(4)
# memory usage: 35.3+ KB

# %%
df.columns
# Out:
# Index(['Order_ID', 'Customer_Age', 'Gender', 'Product', 'Category', 'Price',
#        'Quantity', 'Total_Spend', 'Order_Date'],
#       dtype='object')

# %%
df.describe()
# Out:
#          Order_ID  Customer_Age        Price    Quantity  Total_Spend
# count  500.000000    500.000000   500.000000  500.000000   500.000000
# mean   250.500000     42.152000   974.994000    3.006000  2859.312000
# std    144.481833     13.923528   577.982381    1.414909  2314.244684
# min      1.000000     18.000000    12.000000    1.000000    19.000000
# 25%    125.750000     30.000000   456.500000    2.000000   989.750000
# 50%    250.500000     42.000000   932.500000    3.000000  2105.000000
# 75%    375.250000     55.000000  1505.500000    4.000000  4042.500000
# max    500.000000     65.000000  1999.000000    5.000000  9965.000000

# %%
df.columns
# Out:
# Index(['Order_ID', 'Customer_Age', 'Gender', 'Product', 'Category', 'Price',
#        'Quantity', 'Total_Spend', 'Order_Date'],
#       dtype='object')

# %%
plt.figure(figsize=(9,3))
plt.scatter(df['Category'],df['Price'])
plt.xlabel("Category")
plt.ylabel("Price")
plt.show()

# %%
def bar_plot(variable):
    var=df[variable]
    varValue=var.value_counts()
    plt.figure(figsize=(9,3))
    plt.bar(varValue.index,varValue)
    plt.xticks(varValue.index,varValue.index.values)
    plt.ylabel("Frequency")
    plt.title(variable)
    plt.show()
    print("{}: \n {}".format(variable,varValue))

# %%
df.columns
# Out:
# Index(['Order_ID', 'Customer_Age', 'Gender', 'Product', 'Category', 'Price',
#        'Quantity', 'Total_Spend', 'Order_Date'],
#       dtype='object')

# %%
columns_plot=['Gender', 'Product', 'Category', 'Price','Quantity']
for i in columns_plot:
    bar_plot(i)
# Out:
# Gender:
#  Gender
# Female    269
# Male      231
# Name: count, dtype: int64
# Product:
#  Product
# Sneakers          27
# Coffee Maker      23
# Yoga Mat          23
# Tablet            22
# Face Cream        21
# Jeans             21
# T-Shirt           19
# Foundation        19
# Sandals           18
# Football          18
# Toaster           18
# Tennis Racket     18
# Lipstick          18
# Blender           17
# Formal Shoes      16
# Vacuum Cleaner    16
# Dress             16
# Smartwatch        15
# Jacket            15
# Boots             14
# Slippers          14
# Perfume           14
# Shampoo           14
# Smartphone        13
# Basketball        13
# Headphones        13
# Microwave         13
# Laptop            12
# Dumbbells         12
# Sweater            8
# Name: count, dtype: int64
# Category:
#  Category
# Footwear       89
# Home           87
# Beauty         86
# Sports         84
# Apparel        79
# Electronics    75
# Name: count, dtype: int64
# ...

# %%
df.columns
# Out:
# Index(['Order_ID', 'Customer_Age', 'Gender', 'Product', 'Category', 'Price',
#        'Quantity', 'Total_Spend', 'Order_Date'],
#       dtype='object')

# %%
def hist_plot(variable):
    var=df[variable]
    varValue=var.value_counts()
    plt.figure(figsize=(9,3))
    plt.hist(varValue.index,varValue)
    plt.xticks(varValue.index,varValue.index.values)
    plt.ylabel("Frequency")
    plt.title(variable)
    plt.show()
    print("{}: \n {}".format(variable,varValue))

# %%
columns_plot = ['Order_ID', 'Total_Spend', 'Order_Date', 'Gender']

for i in columns_plot:
    plt.hist(df[i])
    plt.title(i)
    plt.show()

# %%
category_spend = df[['Category', 'Total_Spend']].groupby(['Category'], as_index=False).mean()

# %%
category_spend
# Out:
#       Category  Total_Spend
# 0      Apparel  3138.012658
# 1       Beauty  2849.162791
# 2  Electronics  2418.360000
# 3     Footwear  2676.067416
# 4         Home  2931.045977
# 5       Sports  3121.154762

# %%
df.columns
# Out:
# Index(['Order_ID', 'Customer_Age', 'Gender', 'Product', 'Category', 'Price',
#        'Quantity', 'Total_Spend', 'Order_Date'],
#       dtype='object')

# %%
columns_plot = ['Customer_Age', 'Price', 'Total_Spend', 'Quantity']

for i in columns_plot:
    plt.boxplot(df[i])
    plt.title(i)
    plt.show()

# %%
df.isna()
# Out:
#      Order_ID  Customer_Age  Gender  Product  Category  Price  Quantity  \
# 0       False         False   False    False     False  False     False
# 1       False         False   False    False     False  False     False
# 2       False         False   False    False     False  False     False
# 3       False         False   False    False     False  False     False
# 4       False         False   False    False     False  False     False
# ..        ...           ...     ...      ...       ...    ...       ...
# 495     False         False   False    False     False  False     False
# 496     False         False   False    False     False  False     False
# 497     False         False   False    False     False  False     False
# 498     False         False   False    False     False  False     False
# 499     False         False   False    False     False  False     False
#
#      Total_Spend  Order_Date
# 0          False       False
# 1          False       False
# ...

# %%
df.isna().sum()
# Out:
# Order_ID        0
# Customer_Age    0
# Gender          0
# Product         0
# Category        0
# Price           0
# Quantity        0
# Total_Spend     0
# Order_Date      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order_ID      500 non-null    int64
#  1   Customer_Age  500 non-null    int64
#  2   Gender        500 non-null    object
#  3   Product       500 non-null    object
#  4   Category      500 non-null    object
#  5   Price         500 non-null    int64
#  6   Quantity      500 non-null    int64
#  7   Total_Spend   500 non-null    int64
#  8   Order_Date    500 non-null    object
# dtypes: int64(5), object(4)
# memory usage: 35.3+ KB

# %%
df = pd.get_dummies(df, columns=['Gender', 'Product', 'Category', 'Order_Date'], drop_first=True)

# %%
df.head()
# Out:
#    Order_ID  Customer_Age  Price  Quantity  Total_Spend  Gender_Male  \
# 0         1            64   1627         4         6508         True
# 1         2            43    165         3          495        False
# 2         3            62   1367         4         5468        False
# 3         4            56   1078         5         5390        False
# 4         5            35   1940         2         3880         True
#
#    Product_Blender  Product_Boots  Product_Coffee Maker  Product_Dress  ...  \
# 0            False          False                 False          False  ...
# 1            False          False                 False          False  ...
# 2            False          False                 False          False  ...
# 3            False          False                 False          False  ...
# 4            False          False                 False          False  ...
#
#    Order_Date_2023-12-22  Order_Date_2023-12-23  Order_Date_2023-12-24  \
# ...

# %%
df_numeric = df.select_dtypes(include=['number'])

# %%
corr_matrix = df_numeric.corr()
plt.figure(figsize=(10, 6))  
sns.heatmap(corr_matrix, annot=True, fmt=".2f")
plt.show()
